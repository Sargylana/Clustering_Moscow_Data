# %% [markdown]
# ## Data Collecting and Processing

# %% [markdown]
# ### Venues new Moscow subway stations

# %% [markdown]
# Data is collected as following:
# 1. I found the list of subway stations and their locations in Wikipedia
# 2. I used Foursquare API to get the most common venues of given borough of Moscow

# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd

# %%
source = requests.get('https://en.wikipedia.org/wiki/List_of_Moscow_Metro_stations').text
soup=BeautifulSoup(source,'lxml')

# %%
soup_ = soup.find_all('tbody')
td_list = soup_[1].find_all('td')

# %%
tr_list=soup_[1].find_all('tr')
print (tr_list[1].get_text(' ').split('\n')[3].strip())
print (tr_list[1].get_text(' ').split('\n')[15].split('/')[0].split(' ')[1].strip())
print (tr_list[1].get_text(' ').split('\n')[15].split('/')[0].split(' ')[4].strip())
# Out:
# Bulvar Rokossovskogo
# 55°48′53″N
# 37°44′03″E

# %%
import re

# %%
metro=[]
for tr in tr_list[1:]:
    name = tr.get_text(' ').split('\n')[3].strip()
    #print (name)
    lat_ = tr.get_text(' ').split('\n')[15].split('/')[0].split(' ')[1].strip()
    #print (lat_)
    lon_ = tr.get_text(' ').split('\n')[15].split('/')[0].split(' ')[4].strip()
    #print (lon_)
    
    deg, minutes, seconds, direction =  re.split('[°\′″]', lat_)
    lat2=(float(deg) + float(minutes)/60 + float(seconds)/(60*60)) * (-1 if direction in ['W', 'S'] else 1)
    
    deg, minutes, seconds, direction =  re.split('[°\′″]', lon_)
    lon2=(float(deg) + float(minutes)/60 + float(seconds)/(60*60)) * (-1 if direction in ['W', 'S'] else 1)
    
   
    metro.append([name, lat_, lon_, lat2, lon2])

# %%
df= pd.DataFrame(metro,columns=['metro', 'lat','lon','lat2','lon2'])

# %%
df.head()
# Out:
#                         metro         lat         lon       lat2       lon2
# 0        Bulvar Rokossovskogo  55°48′53″N  37°44′03″E  55.814722  37.734167
# 1              Cherkizovskaya  55°48′14″N  37°44′41″E  55.803889  37.744722
# 2  Preobrazhenskaya Ploshchad  55°47′47″N  37°42′54″E  55.796389  37.715000
# 3                   Sokolniki  55°47′20″N  37°40′49″E  55.788889  37.680278
# 4              Krasnoselskaya  55°46′48″N  37°40′02″E  55.780000  37.667222

# %%
df.shape
# Out:
# (261, 5)

# %%
latitude=df['lat2'][0]
longitude = df['lon2'][0]

# %%
import folium

# %%
map_metro = folium.Map(location=[latitude, longitude], zoom_start=10)

# add markers to map
for lat, lng, metro in zip(df['lat2'], df['lon2'], df['metro']):
    label = '{}'.format(metro)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_metro)  
    
map_metro
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Data Analysis

# %%
CLIENT_ID = 'Z25GUICIFLP0Q3Y4SCOWGQI13UMLKHAAGO5E3QCAJPWE41QE' # your Foursquare ID
CLIENT_SECRET = 'O4ELSZ33RPCYJS3DGNDYAWTVA3QM5RP3ZGHA2JDALWZCKSH2' # your Foursquare Secret
VERSION = '20180605' # Foursquare API version
LIMIT =30

print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: Z25GUICIFLP0Q3Y4SCOWGQI13UMLKHAAGO5E3QCAJPWE41QE
# CLIENT_SECRET:O4ELSZ33RPCYJS3DGNDYAWTVA3QM5RP3ZGHA2JDALWZCKSH2

# %%
import requests # library to handle requests
from pandas.io.json import json_normalize

# %%
def getNearbyVenues(names, latitudes, longitudes, radius=750):
    
    venues_list=[]
    for name, lat, lng in zip(names, latitudes, longitudes):
        print(name)
            
        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT)
            
        # make the GET request
        results = requests.get(url).json()["response"]['groups'][0]['items']
        
        # return only relevant information for each nearby venue
        venues_list.append([(
            name, 
            lat, 
            lng, 
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['
#
#                         Venue  Venue Latitude  Venue Longitude  \
# 0                    Подружка       55.814523        37.736781
# 1                 Burger King       55.814026        37.733659
# 2               Fitlab studio       55.810845        37.727964
# 3         Галерея Богородское       55.813944        37.734298
# 4  Ветеринарная Аптека Ветлек       55.813464        37.735036
#
#          Venue Category               Summary
# 0        Cosmetics Shop  This spot is popular
# 1  Fast Food Restaurant  This spot is popular
# 2  Gym / Fitness Center  This spot is popular
# 3           Art Gallery  This spot is popular
# 4             Pet Store  This spot is popular

# %%
print('There are {} uniques categories.'.format(len(moscow_venues['Venue Category'].unique())))
# Out:
# There are 359 uniques categories.

# %%
moscow_venues['Venue Category'].unique()
# Out:
# array(['Cosmetics Shop', 'Fast Food Restaurant', 'Gym / Fitness Center',
#        'Art Gallery', 'Pet Store', 'Vietnamese Restaurant',
#        'Auto Workshop', 'Candy Store', 'Mobile Phone Shop', 'Park',
#        'Café', 'Butcher', 'Tex-Mex Restaurant', 'Sushi Restaurant',
#        'Asian Restaurant', 'Shoe Store', 'Coffee Shop', 'Bookstore',
#        'Bus Line', 'Gift Shop', 'Dance Studio', 'Supermarket',
#        'Convenience Store', 'Bus Stop', 'Tennis Stadium', 'Museum',
#        'Arcade', 'Soccer Stadium', 'Sports Bar', 'Sporting Goods Shop',
#        'Martial Arts Dojo', 'Flower Shop', 'Soccer Field', 'Hockey Arena',
#        'Performing Arts Venue', 'Hookah Bar', 'Arts & Crafts Store',
#        'Hotel', 'Trail', 'Pizza Place', 'Hobby Shop', 'Stadium',
#        'Photography Lab', 'Playground', 'Health Food Store', 'Gym',
#        'Farmers Market', 'Boxing Gym', 'Salon / Barbershop', 'Pharmacy',
#        'Sandwich Place', 'Eastern European Restaurant', 'Burger Joint',
#        'Breakfast Spot', 'Steakhouse', 'Plaza', 'Food & Drink Shop',
#        'Herbs & Spices Store', 'Kids Store', 'Chinese Restaurant',
#        'Dessert Shop', 'Beer Bar', 'Clothing Store',
#        'Modern European Restaurant', 'Gourmet Shop', 'Music School',
#        'Board Shop', 'Toy / Game Store', 'Climbing Gym', 'Bike Shop',
#        'Creperie', 'Noodle House', 'Boutique', 'Fabric Shop', 'Fountain',
#        'Theater', 'Hockey Field', 'Wings Joint', 'Motorcycle Shop', 'Spa',
#        'Gay Bar', 'Pool', 'Brewery', 'Bed & Breakfast', 'Pub',
#        'Ice Cream Shop', 'Hotel Bar', 'Varenyky restaurant',
#        'Concert Hall', 'Hunting Supply', 'Seafood Restaurant', 'Bakery',
#        'Health & Beauty Service', 'Pie Shop', 'Athletics & Sports',
#        'Restaurant', 'Accessories Store', 'Palace', 'Korean Restaurant',
#        'Middle Eastern Restaurant', 'Electronics Store',
#        'Caucasian Restaurant', 'Historic Site', 'Belgian Restaurant',
#        'Garden', 'Paper / Office Supplies Store', 'Italian Restaurant',
#        'Dive Bar', 'Tea Room', 'Yoga Studio', 'Jewelry Store',
#        'Gymnastics Gym', 'Japanese Restaurant', 'Hostel', 'Gaming Cafe',
#        'Scenic Lookout', 'Other Repair Shop', 'French Restaurant',
#        'Multiplex', 'Pedestrian Plaza', 'Shopping Mall', 'Irish Pub',
#        'Food Court', 'Russian Restaurant', 'History Museum',
#        'Opera House', 'Road', 'Event Space', 'Ukrainian Restaurant',
#        'Government Building', 'Art Museum', 'Music Venue', 'Wine Bar',
#        "Women's Store", 'Massage Studio', 'Bulgarian Restaurant',
#        'Wine Shop', 'Cocktail Bar', 'Movie Theater',
#        'Street Food Gathering', 'Strip Club', 'Vape Store',
#        'Bike Rental / Bike Share', 'Mediterranean Restaurant', 'Bistro',
#        'Scandinavian Restaurant', 'Pilates Studio', 'Music Store',
#        'Bath House', 'Furniture / Home Store', 'Monastery', 'BBQ Joint',
#        'English Restaurant', 'Deli / Bodega', 'Outdoor Gym', 'Beach',
#        'Basketball Court', 'Track Stadium', 'Skate Park', 'Tennis Court',
#        'Lounge', 'Exhibit', 'Udon Restaurant', 'Kitchen Supply Store',
#        'Circus', 'Tapas Restaurant', 'Baby Store', 'Food', 'Blini House',
#        'Optical Shop', 'Fried Chicken Joint', 'Other Great Outdoors',
#        'Mexican Restaurant', 'Stables', 'Outdoor Sculpture',
#        'Dry Cleaner', 'Bowling Alley', 'Salad Place', 'Donut Shop',
#        'Moving Target', 'Print Shop', 'Big Box Store', 'Department Store',
#        'Metro Station', 'Gastropub', 'Buffet', 'Shawarma Place',
#        'Campground', 'Gym Pool', 'Film Studio', 'Shop & Service',
#        'Shoe Repair', 'Theme Park', 'Beer Store', 'Indian Restaurant',
#        'Lingerie Store', 'Indie Theater', 'Science Museum', 'Salsa Club',
#        'Juice Bar', 'Liquor Store', "Men's Store", 'Adult Boutique',
#        'Theme Park Ride / Attraction', 'General Entertainment', 'Dog Run',
#        'Cycle Studio', 'Bar', 'Vegetarian / Vegan Restaurant',
#        'Soup Place', 'Bagel Shop', 'Bridal Shop', 'Thai Restaurant',
#        'Jazz Club', 'Comic Shop', 'Argentinian Restaurant',
#        'Cupcake Shop', 'Photography Studio', 'Nightclub', 'Office',
#        'Pelmeni House', 'Zoo Exhibit', 'Waterfront', 'Shipping Store',
#        'Market', 'Flea Market', 'Tour Provider', 'Miscellaneous Shop',
#        'Gas Station', 'Platform', 'Grocery Store', 'Boat Rental', 'Lake',
#        'Castle', 'Sculpture Garden', 'Volleyball Court', 'Travel Agency',
#        'Public Art', 'Nail Salon', 'Dairy Store', 'Racetrack', 'Resort',
#        'Aquarium', 'Sauna / Steam Room', 'Frozen Yogurt Shop', 'Notary',
#        'Gun Range', 'Roof Deck', 'Record Shop', 'Pool Hall',
#        'Sports Club', 'Arts & Entertainment', 'Watch Shop',
#        'Camera Store', 'Jewish Restaurant', 'Israeli Restaurant',
#        'University', 'Skating Rink', 'Perfume Shop', 'Trade School',
#        'Cafeteria', 'Video Game Store', 'Smoke Shop', 'Supplement Shop',
#        'Taxi', 'Harbor / Marina', 'Hardware Store', 'Fish Market',
#        'Frame Store', 'Go Kart Track', 'Recording Studio', 'Tailor Shop',
#        'Halal Restaurant', 'Poke Place', 'Cheese Shop', 'Zoo',
#        'Planetarium', 'Peruvian Restaurant', 'Library', 'Taco Place',
#        'Indie Movie Theater', 'Street Art', 'Karaoke Bar',
#        'Coworking Space', 'Botanical Garden', 'Dumpling Restaurant',
#        'Squash Court', 'Light Rail Station', 'Tourist Information Center',
#        'Snack Place', 'Fishing Store', 'Warehouse Store', 'Train Station',
#        'Turkish Restaurant', 'Diner', 'German Restaurant',
#        'Theme Restaurant', 'Drugstore', 'ATM', 'Medical Center',
#        'American Restaurant', 'Organic Grocery', 'Burrito Place', 'Hill',
#        'Betting Shop', 'College Gym', 'Non-Profit', 'Paintball Field',
#        'Neighborhood', 'Greek Restaurant', 'Tunnel', 'Luggage Store',
#        'Curling Ice', 'Track', 'Pet Service',
#        'Construction & Landscaping', 'Comedy Club', 'Rest Area', 'Forest',
#        'Indoor Play Area', 'Hockey Rink', 'Nursery School', 'Car Wash',
#        'Ski Trail', 'Dive Spot', 'Other Nightlife', 'Water Park',
#        'Outdoor Supply Store', 'Tree', 'Golf Course', 'Stationery Store',
#        'Tattoo Parlor', 'Design Studio', 'Fruit & Vegetable Store',
#        'Pastry Shop', 'Bank', 'Ski Area', 'Swiss Restaurant', 'Ski Lodge',
#        'Hot Dog Joint', 'Factory', 'Bus Station', 'Rugby Stadium',
#        'Moroccan Restaurant', 'Chocolate Shop', 'Carpet Store', 'River',
#        'Tanning Salon', 'Basketball Stadium', 'Falafel Restaurant',
#        'Garden Center', 'Tram Station', 'Discount Store',
#        'Monument / Landmark', 'Bridge', 'Souvenir Shop',
#        'Cuban Restaurant', 'Auto Dealership', 'Rock Climbing Spot'],
#       dtype=object)

# %%
moscow_venues['Venue Category'].value_counts().head()
# Out:
# Coffee Shop             347
# Gym / Fitness Center    213
# Cosmetics Shop          198
# Park                    190
# Supermarket             170
# Name: Venue Category, dtype: int64

# %%
moscow_venues[moscow_venues['Venue Category']=='Coffee Shop'].head()
# Out:
#                    Neighborhood  Neighborhood Latitude  \
# 16         Bulvar Rokossovskogo              55.814722
# 60   Preobrazhenskaya Ploshchad              55.796389
# 62   Preobrazhenskaya Ploshchad              55.796389
# 80   Preobrazhenskaya Ploshchad              55.796389
# 116              Krasnoselskaya              55.780000
#
#      Neighborhood Longitude        Venue  Venue Latitude  Venue Longitude  \
# 16                37.734167   Культ Кофе       55.813573        37.734943
# 60                37.715000    Starbucks       55.795299        37.712556
# 62                37.715000  Coffee Port       55.795361        37.712711
# 80                37.715000  Правда Кофе       55.795795        37.712796
# 116               37.667222  Шоколадница       55.779720        37.666591
#
#     Venue Category               Summary
# 16     Coffee Shop  This spot is popular
# 60     Coffee Shop  This spot is popular
# 62     Coffee Shop  This spot is popular
# 80     Coffee Shop  This spot is popular
# 116    Coffee Shop  This spot is popular

# %%
moscow_venues.head()
# Out:
#            Neighborhood  Neighborhood Latitude  Neighborhood Longitude  \
# 0  Bulvar Rokossovskogo              55.814722               37.734167
# 1  Bulvar Rokossovskogo              55.814722               37.734167
# 2  Bulvar Rokossovskogo              55.814722               37.734167
# 3  Bulvar Rokossovskogo              55.814722               37.734167
# 4  Bulvar Rokossovskogo              55.814722               37.734167
#
#                         Venue  Venue Latitude  Venue Longitude  \
# 0                    Подружка       55.814523        37.736781
# 1                 Burger King       55.814026        37.733659
# 2               Fitlab studio       55.810845        37.727964
# 3         Галерея Богородское       55.813944        37.734298
# 4  Ветеринарная Аптека Ветлек       55.813464        37.735036
#
#          Venue Category               Summary
# 0        Cosmetics Shop  This spot is popular
# 1  Fast Food Restaurant  This spot is popular
# 2  Gym / Fitness Center  This spot is popular
# 3           Art Gallery  This spot is popular
# 4             Pet Store  This spot is popular

# %%
moscow_venues=moscow_venues.drop(columns=['Summary'])

# %%
moscow_venues.head()
# Out:
#            Neighborhood  Neighborhood Latitude  Neighborhood Longitude  \
# 0  Bulvar Rokossovskogo              55.814722               37.734167
# 1  Bulvar Rokossovskogo              55.814722               37.734167
# 2  Bulvar Rokossovskogo              55.814722               37.734167
# 3  Bulvar Rokossovskogo              55.814722               37.734167
# 4  Bulvar Rokossovskogo              55.814722               37.734167
#
#                         Venue  Venue Latitude  Venue Longitude  \
# 0                    Подружка       55.814523        37.736781
# 1                 Burger King       55.814026        37.733659
# 2               Fitlab studio       55.810845        37.727964
# 3         Галерея Богородское       55.813944        37.734298
# 4  Ветеринарная Аптека Ветлек       55.813464        37.735036
#
#          Venue Category
# 0        Cosmetics Shop
# 1  Fast Food Restaurant
# 2  Gym / Fitness Center
# 3           Art Gallery
# 4             Pet Store

# %%
import csv

# %%
#moscow_venues.to_csv(r'C:\Users\Anton\Dropbox\Sargy\#Education\#COURSERA\IBM\moscow_venues_1.csv')

# %%
moscow_data = pd.read_csv(r'C:\Users\Anton\Dropbox\Sargy\#Education\#COURSERA\IBM\moscow_venues_1.csv', index_col='Index_Col')

# %%
moscow_data.head()
# Out:
#                    Neighborhood  Neighborhood Latitude  \
# Index_Col
# 0          Bulvar Rokossovskogo              55.814722
# 1          Bulvar Rokossovskogo              55.814722
# 2          Bulvar Rokossovskogo              55.814722
# 3          Bulvar Rokossovskogo              55.814722
# 4          Bulvar Rokossovskogo              55.814722
#
#            Neighborhood Longitude                       Venue  Venue Latitude  \
# Index_Col
# 0                       37.734167                    Подружка       55.814523
# 1                       37.734167                 Burger King       55.814026
# 2                       37.734167         Галерея Богородское       55.813944
# 3                       37.734167               Fitlab studio       55.810845
# 4                       37.734167  Ветеринарная Аптека Ветлек       55.813464
#
#            Venue Longitude        Venue Category
# Index_Col
# 0                37.736781        Cosmetics Shop
# 1                37.733659  Fast Food Restaurant
# 2                37.734298           Art Gallery
# 3                37.727964  Gym / Fitness Center
# 4                37.735036             Pet Store

# %% [markdown]
# #### Further steps in week 5
# * Get the most common venues per neighborhood
# * Cluster nbeighborhoods using K-mean algorithm
# * Visualize and describe cluster
# * Findings and conclusion
# * References
